# %% [markdown]
# # Visualization: Top N words in positive and negative classes for each language

# %%
# Steps:
# Read all language files into dfs
# Add language name column to df
# Concat / Merge all the dfs vertically

# %%
# !pip install transformers

# %%
import pandas as pd
import numpy as np
import glob
import os
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from nltk.stem.snowball import SnowballStemmer
from itertools import islice
#from transformers import AutoTokenizer

# %% [markdown]
# ## Read Files

# %%
file_names = ['am_train', 'dz_train', 'ha_train', 'ig_train', 'ma_train', 'pcm_train', 'pt_train', 'sw_train', 'yo_train']
def read_file(file_name, language):
    lang_initial = file_name.split("_")
    
    # raw file
    if language == 'African':
        file_path = r'semeval2023-afrisenti-main/data/raw/train/' + file_name + '.tsv'
        df = pd.read_csv(file_path, sep='\t', header=0)
        df.columns = df.columns.str.replace(' ', '')
        df['label'] = df['label'].str.replace(" ", "")
        df_name = 'df_' +  lang_initial[0] 
        
    # english translated file
    else:
        file_path = r'train_afri_to_eng_tsv/' + file_name + '.csv'
        df = pd.read_csv(file_path, sep='\t', header=0)
        df.columns = df.columns.str.replace(' ', '')
        df['label'] = df['label'].str.replace(" ", "")
        df_name = 'df_' + lang_initial[0] + '_eng' 
        
    return df, df_name

# %% [markdown]
# ### Save individual dataframes and store dfs in a dictionary

# %%
raw_dfs_dict ={}
for file_name in file_names:
    df, df_name = read_file(file_name, 'African')
    # Save individual dataframe
    exec(df_name + " = df")
    # Add to dictionary
    raw_dfs_dict[df_name] = df
#print(raw_dfs_dict)

translated_dfs_dict ={}
for file_name in file_names:
    df, df_name = read_file(file_name, 'English')
    # Save individual dataframe
    exec(df_name + " = df")
    # Add to dictionary
    translated_dfs_dict[df_name] = df
#print(translated_dfs_dict)

# %% [markdown]
# ### Testing individual dataframes

# %%
for i in raw_dfs_dict.values():
    print(i.head())
    
for i in translated_dfs_dict.values():
    print(i.head())
# Out:
#                ID                                              tweet     label
# 0  am_train_00001  Tesfaye ለካስ ጭብል ለብሰሽ የፕሮፌሰርን ፎቶ ለጥፈክ እልም ያልክ ባ...  negative
# 1  am_train_00002  ይሄው ነው አይደል የእውቀትሽ ጥግ....በሰሚ ሰሚ ከምትናገሪ ለምን ታሪክ...  negative
# 2  am_train_00003                ዘገበ ይባላል? ሌላ የሚባል ነገር ካለ አንተዉ ንገረን!  negative
# 3  am_train_00004  ?? ድሮ በዘመነ ኮዳክ ፎቶ ቤት ፍላሹ ፏ ሲል አይናችን ተጨፍኖ እንዳይወ...  negative
# 4  am_train_00005                                     ዠልጥ?? ???? ገገማ  negative
#                ID                                              tweet     label
# 0  dz_train_00001  @user على حسب موقعك يبدو أنك صاحب نظرة ثاقبة ....  negative
# 1  dz_train_00002                                  @user تبهليل هاذا  negative
# 2  dz_train_00003                       @user هاذي تبهليل ماشي فهامة  negative
# 3  dz_train_00004  @user @user تخاف نجاوب يا ناصر ببلوك لانو طريق...  negative
# 4  dz_train_00005  @user مرنكة أقسم بالله 😂😂😂تبهليل ما بعد منتصف ...  negative
#                ID                                              tweet     label
# 0  ha_train_00001  @user Da kudin da Arewa babu wani abin azo aga...  negative
# 1  ha_train_00002  @user Kaga wani Adu ar Banda💔😭 wai a haka Shi ...  negative
# 2  ha_train_00003  @user Sai haquri fa yan madrid daman kunce cha...  negative
# 3  ha_train_00004  @user Hmmm yanzu kai kasan girman allah daxaka...  negative
# 4  ha_train_00005  @user @user Wai gwamno nin Nigeria suna afa kw...  negative
#                ID                                              tweet     label
# 0  ig_train_00001       Nna Ike Gwuru ooo. 😂 https://t.co/NDS7juFBGd  negative
# 1  ig_train_00002                 @user Chineke nna kezi mgbe ole???  negative
# 2  ig_train_00003  Lol. Isi adirokwanu gi nma.. 😐😒😒😒 https://t.co...  negative
# 3  ig_train_00004  @user haha. Fulani herdsmen. akpa amu gi retwe...  negative
# 4  ig_train_00005  Nna ghetto di gi na aru biko!!! https://t.co/4...  negative
#                ID                                              tweet     label
# 0  ma_train_00001  hhhhhhhhhhhhhhhhhhhhhh ana ga3ma sma3tt ach ka...   neutral
# 1  ma_train_00002  hhhh hardart jomhorha la fi3lan kadahko lach m...   neutral
# 2  ma_train_00003  : أتفهم العثماني وأتفهم الجدل الشعبي. الحل: حا...   neutral
# 3  ma_train_00004                                كان افظل حاكم عربي'  positive
# 4  ma_train_00005  ماريانو راخوي : خاص المغرب واسبانيا يشرحو للرأ...   neutral
#                 ID                                              tweet  \
# 0  pcm_train_00001  yeah ‍️the guy wants to trend dat was why e jo...
# 1  pcm_train_00002  this life is so funny sef you will work hard a...
# 2  pcm_train_00003  dis is unfair of urcompany goingtowks nw ive b...
# 3  pcm_train_00004  lil wayne don vex me im actually not excited a...
# 4  pcm_train_00005  dis is unfair of ur company going to wks nw iv...
#
#       label
# 0  negative
# 1  negative
# 2  negative
# 3  negative
# 4  negative
#                ID                                              tweet     label
# 0  pt_train_00001  Pedi uma resposta a Deus, ele deu me. Estou mu...  negative
# 1  pt_train_00002  Só queria poder voltar no tempo e fazer difere...  negative
# 2  pt_train_00003  @user Este tipo é execrável! Muito pior que pa...  negative
# 3  pt_train_00004  Tem gajos que só de você atravessar estrada 🛣,...  negative
# 4  pt_train_00005  Esses gajos de Yababuluko têm mng barulho nos ...  negative
#                ID                                              tweet     label
# 0  sw_train_00001  Kwani tanesco wanakataga umeme makusudinadhani...  negative
# 1  sw_train_00002  cjawahi kuona content yoyote zaidi ya kuwa ana...  negative
# 2  sw_train_00003  Bomu lililokuwa limetegwa ndani ya gari likiwa...  negative
# 3  sw_train_00004  Kuna video inasambaa mitandaoni jamaa amemfuma...  negative
# 4  sw_train_00005  Viwavijeshi wanapita katika hatua kuu 6 za uku...  negative
#                ID                                              tweet     label
# 0  yo_train_00001  Ìwọ ikú òpònú abaradúdú wọ, o ò ṣe é 're o. O ...  negative
# 1  yo_train_00002  Yorùbá nbú'yàn ṣá """"""""..àyà wanle bí òkú ì...  negative
# 2  yo_train_00003  Òwe àgbà ní """"""""ọmọlọ́mọ là á rán níṣẹ́ à ...  negative
# 3  yo_train_00004  RT @user: @user asa kasa ti awon eyan ko ni od...  negative
# 4  yo_train_00005  RT @user: Mo ń rí àwọn èébú kọ̀ọ̀kan. Àti àwọn...  negative
#                ID                                              tweet     label
# 0  am_train_00001   Tesfaye, you posted a picture of a professor ...  negative
# 1  am_train_00002    This is the corner of your knowledge, isn't it?  negative
# 2  am_train_00003   Is it called a report? If there is anything e...  negative
# 3  am_train_00004   ?? It reminded me of what we used to do in th...  negative
# 4  am_train_00005                    Is it clear?? ???? He recovered  negative
#                 ID                                              tweet  \
# 0   dz_train_00001   @user According to your site, you seem to hav...
# 1   dz_train_00002                                 @user it's amazing
# 2   dz_train_00003                               @user it's hilarious
# 3   dz_train_00004  @user @user You are afraid to answer Nasser in...
# 4   dz_train_00005   @user mrnka I swear to God 😂😂😂 Depression aft...
#
#       label
# 0  negative
# 1  negative
# 2  negative
# 3  negative
# 4  negative
#                 ID                                              tweet  \
# 0   ha_train_00001   @user With the money of the North, there is n...
# 1   ha_train_00002   @user Do you have any Adu ar Banda 💔😭 he is t...
# 2   ha_train_00003   @user Be patient, madrid, you have many chanc...
# 3   ha_train_00004  @user Hmmm now you are below the greatness of ...
# 4   ha_train_00005   @user @user The Nigerian governors are sellin...
#
#       label
# 0  negative
# 1  negative
# 2  negative
# 3  negative
# 4  negative
#                ID                                              tweet     label
# 0  ig_train_00001      Father Ike Dig ooo. 😂 https://t.co/NDS7juFBGd  negative
# 1  ig_train_00002                       @user God father how long???  negative
# 2  ig_train_00003   Lol. Your head is beautiful too.. 😐😒😒😒 https:...  negative
# 3  ig_train_00004   @user lol. Fulani herdsmen. Please retweet. E...  negative
# 4  ig_train_00005   The ghetto father is in your body please!!! h...  negative
#                 ID                                              tweet  \
# 0   my_train_00001  hhhhhhhhhhhhhhhhhhhhh ana ga3ma sma3tt ach kan...
# 1   my_train_00002   hhhh hardart jomhorha la fi3lan kadahko lach ...
# 2   my_train_00003   : I understand Othmani and the popular debate...
# 3   my_train_00004                        He was the best Arab ruler.
# 4   my_train_00005   Mariano Rajoy: In particular, Morocco and Spa...
#
#       label
# 0   neutral
# 1   neutral
# 2   neutral
# 3  positive
# 4   neutral
#                 ID                                              tweet  \
# 0  pcm_train_00001  yeah ‍️the guy wants to trend dat was why e jo...
# 1  pcm_train_00002  this life is so funny sef you will work hard a...
# 2  pcm_train_00003  dis is unfair of urcompany goingtowks nw ive b...
# 3  pcm_train_00004  lil wayne don vex me im actually not excited a...
# 4  pcm_train_00005  dis is unfair of ur company going to wks nw iv...
#
#       label
# 0  negative
# 1  negative
# 2  negative
# 3  negative
# 4  negative
#                ID                                              tweet     label
# 0  pt_train_00001   I asked God for an answer, he gave it to me. ...  negative
# 1  pt_train_00002   I just wish I could go back in time and do it...  negative
# 2  pt_train_00003   @user This type is executable! Much worse tha...  negative
# 3  pt_train_00004   There are guys that just you cross the road 🛣...  negative
# 4  pt_train_00005   These guys from Yababuluko have a lot of nois...  negative
#                ID                                              tweet     label
# 0  sw_train_00001  Because Tanesco is deliberately cutting off el...  negative
# 1  sw_train_00002   I have never seen any content other than that...  negative
# 2  sw_train_00003   A bomb planted in a car targeting Turkish bui...  negative
# 3  sw_train_00004   There is a video circulating on the internet ...  negative
# 4  sw_train_00005   The caterpillars go through 6 main growth sta...  negative
#                ID                                              tweet     label
# 0  yo_train_00001  You black-headed death, you didn't do it. You ...  negative
# 1  yo_train_00002       Yoruba keeps crying """"""". :) #ebu #Yoruba  negative
# 2  yo_train_00003   The highest proverb had "" "" "" "" "" "" "" ...  negative
# 3  yo_train_00004   RT @user: @user the culture of people who don...  negative
# 4  yo_train_00005   RT @user: I see each and every one of them. A...  negative

# %% [markdown]
# ### Combine Dataframes

# %%
# Combine Data Files

def merge_data_files(path, suffix):
    all_files = glob.glob(os.path.join(path , '*' + suffix))
    df_list = []
    
    for filename in all_files:
        df = pd.read_csv(filename, index_col=None, sep='\t', header=0)
        newfilename = filename.split("\\")
        language = newfilename[1].replace(suffix, "")
        df['language'] = language
        df.columns = df.columns.str.replace(' ', '')
        df['label'] = df['label'].str.replace(" ", "")
        df_list.append(df)
    
    df_combined = pd.concat(df_list, axis=0, ignore_index=True) 
    return df_combined

# %%
df_raw_combined = merge_data_files(r'semeval2023-afrisenti-main/data/raw/train/', '_train.tsv')
df_raw_combined
# Out:
#                    ID                                              tweet  \
# 0      am_train_00001  Tesfaye ለካስ ጭብል ለብሰሽ የፕሮፌሰርን ፎቶ ለጥፈክ እልም ያልክ ባ...
# 1      am_train_00002  ይሄው ነው አይደል የእውቀትሽ ጥግ....በሰሚ ሰሚ ከምትናገሪ ለምን ታሪክ...
# 2      am_train_00003                ዘገበ ይባላል? ሌላ የሚባል ነገር ካለ አንተዉ ንገረን!
# 3      am_train_00004  ?? ድሮ በዘመነ ኮዳክ ፎቶ ቤት ፍላሹ ፏ ሲል አይናችን ተጨፍኖ እንዳይወ...
# 4      am_train_00005                                     ዠልጥ?? ???? ገገማ
# ...               ...                                                ...
# 56093  yo_train_08518  RT @user: Oju adan o'nribi, oju awodi o'nri or...
# 56094  yo_train_08519  a tú dúpẹ́ lọ́wọ́ àwọn alátakò wá náà, a ó gbọ...
# 56095  yo_train_08520  Ẹní tó làná, tó lòní, kò leè lọ̀la; Ọlọ́run nì...
# 56096  yo_train_08521  My God is """"""""onise iyanu"""""""" ( A Mira...
# 56097  yo_train_08522  RT @user: Ẹ wá ba mi re! #yorubafood #naijafoo...
#
#           label language
# 0      negative       am
# 1      negative       am
# 2      negative       am
# 3      negative       am
# 4      negative       am
# ...         ...      ...
# 56093  positive       yo
# 56094  positive       yo
# 56095  positive       yo
# 56096  positive       yo
# 56097  positive       yo
#
# [56098 rows x 4 columns]

# %%
df_raw_combined.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56098 entries, 0 to 56097
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   ID        56098 non-null  object
#  1   tweet     56098 non-null  object
#  2   label     56098 non-null  object
#  3   language  56098 non-null  object
# dtypes: object(4)
# memory usage: 1.7+ MB

# %%
df_raw_combined.shape
# Out:
# (56098, 4)

# %%
df_translated_combined = merge_data_files(r'train_afri_to_eng_tsv/', '_train.csv')
df_translated_combined
# Out:
#                    ID                                              tweet  \
# 0      am_train_00001   Tesfaye, you posted a picture of a professor ...
# 1      am_train_00002    This is the corner of your knowledge, isn't it?
# 2      am_train_00003   Is it called a report? If there is anything e...
# 3      am_train_00004   ?? It reminded me of what we used to do in th...
# 4      am_train_00005                    Is it clear?? ???? He recovered
# ...               ...                                                ...
# 56093  yo_train_08518   RT @user: The eyes of a bat are here, the eye...
# 56094  yo_train_08519   We are grateful to our opponents, we will be ...
# 56095  yo_train_08520  The person who was yesterday, who is today, ca...
# 56096  yo_train_08521                 My God is a miracle worker #yoruba
# 56097  yo_train_08522   RT @user: Come join me! #yorubafood #naijafoo...
#
#           label language
# 0      negative       am
# 1      negative       am
# 2      negative       am
# 3      negative       am
# 4      negative       am
# ...         ...      ...
# 56093  positive       yo
# 56094  positive       yo
# 56095  positive       yo
# 56096  positive       yo
# 56097  positive       yo
#
# [56098 rows x 4 columns]

# %%
df_translated_combined.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56098 entries, 0 to 56097
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   ID        56098 non-null  object
#  1   tweet     56098 non-null  object
#  2   label     56098 non-null  object
#  3   language  56098 non-null  object
# dtypes: object(4)
# memory usage: 1.7+ MB

# %%
df_translated_combined.shape
# Out:
# (56098, 4)

# %% [markdown]
# ## Data Exploration:

# %%
df_am.head()
# Out:
#                ID                                              tweet     label
# 0  am_train_00001  Tesfaye ለካስ ጭብል ለብሰሽ የፕሮፌሰርን ፎቶ ለጥፈክ እልም ያልክ ባ...  negative
# 1  am_train_00002  ይሄው ነው አይደል የእውቀትሽ ጥግ....በሰሚ ሰሚ ከምትናገሪ ለምን ታሪክ...  negative
# 2  am_train_00003                ዘገበ ይባላል? ሌላ የሚባል ነገር ካለ አንተዉ ንገረን!  negative
# 3  am_train_00004  ?? ድሮ በዘመነ ኮዳክ ፎቶ ቤት ፍላሹ ፏ ሲል አይናችን ተጨፍኖ እንዳይወ...  negative
# 4  am_train_00005                                     ዠልጥ?? ???? ገገማ  negative

# %%
df_am.shape
# Out:
# (5984, 3)

# %%
df_dz.head()
# Out:
#                ID                                              tweet     label
# 0  dz_train_00001  @user على حسب موقعك يبدو أنك صاحب نظرة ثاقبة ....  negative
# 1  dz_train_00002                                  @user تبهليل هاذا  negative
# 2  dz_train_00003                       @user هاذي تبهليل ماشي فهامة  negative
# 3  dz_train_00004  @user @user تخاف نجاوب يا ناصر ببلوك لانو طريق...  negative
# 4  dz_train_00005  @user مرنكة أقسم بالله 😂😂😂تبهليل ما بعد منتصف ...  negative

# %%
df_dz.shape
# Out:
# (1651, 3)

# %%
df_ha.head()
# Out:
#                ID                                              tweet     label
# 0  ha_train_00001  @user Da kudin da Arewa babu wani abin azo aga...  negative
# 1  ha_train_00002  @user Kaga wani Adu ar Banda💔😭 wai a haka Shi ...  negative
# 2  ha_train_00003  @user Sai haquri fa yan madrid daman kunce cha...  negative
# 3  ha_train_00004  @user Hmmm yanzu kai kasan girman allah daxaka...  negative
# 4  ha_train_00005  @user @user Wai gwamno nin Nigeria suna afa kw...  negative

# %%
df_ha.shape
# Out:
# (14172, 3)

# %%
df_ig.head()
# Out:
#                ID                                              tweet     label
# 0  ig_train_00001       Nna Ike Gwuru ooo. 😂 https://t.co/NDS7juFBGd  negative
# 1  ig_train_00002                 @user Chineke nna kezi mgbe ole???  negative
# 2  ig_train_00003  Lol. Isi adirokwanu gi nma.. 😐😒😒😒 https://t.co...  negative
# 3  ig_train_00004  @user haha. Fulani herdsmen. akpa amu gi retwe...  negative
# 4  ig_train_00005  Nna ghetto di gi na aru biko!!! https://t.co/4...  negative

# %%
df_ig.shape
# Out:
# (10192, 3)

# %%
df_ma.head()
# Out:
#                ID                                              tweet     label
# 0  ma_train_00001  hhhhhhhhhhhhhhhhhhhhhh ana ga3ma sma3tt ach ka...   neutral
# 1  ma_train_00002  hhhh hardart jomhorha la fi3lan kadahko lach m...   neutral
# 2  ma_train_00003  : أتفهم العثماني وأتفهم الجدل الشعبي. الحل: حا...   neutral
# 3  ma_train_00004                                كان افظل حاكم عربي'  positive
# 4  ma_train_00005  ماريانو راخوي : خاص المغرب واسبانيا يشرحو للرأ...   neutral

# %%
df_ma.shape
# Out:
# (5583, 3)

# %%
df_pcm.head()
# Out:
#                 ID                                              tweet  \
# 0  pcm_train_00001  yeah ‍️the guy wants to trend dat was why e jo...
# 1  pcm_train_00002  this life is so funny sef you will work hard a...
# 2  pcm_train_00003  dis is unfair of urcompany goingtowks nw ive b...
# 3  pcm_train_00004  lil wayne don vex me im actually not excited a...
# 4  pcm_train_00005  dis is unfair of ur company going to wks nw iv...
#
#       label
# 0  negative
# 1  negative
# 2  negative
# 3  negative
# 4  negative

# %%
df_pcm.shape
# Out:
# (5121, 3)

# %%
df_pt.head()
# Out:
#                ID                                              tweet     label
# 0  pt_train_00001  Pedi uma resposta a Deus, ele deu me. Estou mu...  negative
# 1  pt_train_00002  Só queria poder voltar no tempo e fazer difere...  negative
# 2  pt_train_00003  @user Este tipo é execrável! Muito pior que pa...  negative
# 3  pt_train_00004  Tem gajos que só de você atravessar estrada 🛣,...  negative
# 4  pt_train_00005  Esses gajos de Yababuluko têm mng barulho nos ...  negative

# %%
df_pt.shape
# Out:
# (3063, 3)

# %%
df_sw.head()
# Out:
#                ID                                              tweet     label
# 0  sw_train_00001  Kwani tanesco wanakataga umeme makusudinadhani...  negative
# 1  sw_train_00002  cjawahi kuona content yoyote zaidi ya kuwa ana...  negative
# 2  sw_train_00003  Bomu lililokuwa limetegwa ndani ya gari likiwa...  negative
# 3  sw_train_00004  Kuna video inasambaa mitandaoni jamaa amemfuma...  negative
# 4  sw_train_00005  Viwavijeshi wanapita katika hatua kuu 6 za uku...  negative

# %%
df_sw.shape
# Out:
# (1810, 3)

# %%
df_yo.head()
# Out:
#                ID                                              tweet     label
# 0  yo_train_00001  Ìwọ ikú òpònú abaradúdú wọ, o ò ṣe é 're o. O ...  negative
# 1  yo_train_00002  Yorùbá nbú'yàn ṣá """"""""..àyà wanle bí òkú ì...  negative
# 2  yo_train_00003  Òwe àgbà ní """"""""ọmọlọ́mọ là á rán níṣẹ́ à ...  negative
# 3  yo_train_00004  RT @user: @user asa kasa ti awon eyan ko ni od...  negative
# 4  yo_train_00005  RT @user: Mo ń rí àwọn èébú kọ̀ọ̀kan. Àti àwọn...  negative

# %%
df_yo.shape
# Out:
# (8522, 3)

# %% [markdown]
# ### Plotting

# %%
df2 = df_raw_combined.groupby(['language'])['language'].count()

# %%
df2
# Out:
# Language
# am      5984
# dz      1651
# ha     14172
# ig     10192
# ma      5583
# pcm     5121
# pt      3063
# sw      1810
# yo      8522
# Name: Language, dtype: int64

# %%
df3 = df_raw_combined.groupby('language').size().plot(kind='bar') #, color=['#B81D13','#F7DB80','#008450'])
plt.xlabel('Language')
plt.ylabel('Count')
# Out:
# Text(0,0.5,'Count')

# %%
df4 = df_raw_combined.groupby(['language','label'])['language'].count()

# %%
df4
# Out:
# Language  label
# am        negative    1548
#           neutral     3104
#           positive    1332
# dz        negative     892
#           neutral      342
#           positive     417
# ha        negative    4573
#           neutral     4912
#           positive    4687
# ig        negative    2600
#           neutral     4508
#           positive    3084
# ma        negative    1664
#           neutral     2161
#           positive    1758
# pcm       negative    3241
#           neutral       72
#           positive    1808
# pt        negative     782
#           neutral     1600
#           positive     681
# sw        negative     191
#           neutral     1072
#           positive     547
# yo        negative    1872
#           neutral     3108
#           positive    3542
# Name: Language, dtype: int64

# %%
df5 = df_raw_combined.groupby(['label'])['language'].count()

# %%
df5
# Out:
# label
# negative    17363
# neutral     20879
# positive    17856
# Name: Language, dtype: int64

# %%
df6 = df_raw_combined.groupby('label').size().plot(kind='bar', color=['#B81D13','#F7DB80','#008450'])
plt.xlabel('label')
plt.ylabel('count')
# Out:
# Text(0,0.5,'count')

# %%
sns.countplot(data=df_raw_combined, x="language", hue="label")

# %%
sequential_colors = sns.color_palette("RdYlGn", 3)
sns.countplot(data=df_raw_combined, x="language", hue="label", palette=sequential_colors)

# %% [markdown]
# # Top N words

# %% [markdown]
# ### Top N occurances using Countvectorizer

# %%
def top_n_words(df_n):
    
    # setting up our CountVectorizer
    cvec = CountVectorizer(stop_words='english', min_df=1, max_df=.5, ngram_range=(1,2))
    # print(cvec)
    stemmer = SnowballStemmer("english")
    
    print(df_n.head())
    
    df_n['stemmed'] = df_n.tweet.map(lambda x: ' '.join([stemmer.stem(y) for y in x.split(' ')]))
    # df.stemmed.head()
    
    # Calculate all the n-grams found in all documents
    cvec.fit(df_n.stemmed)
    list(islice(cvec.vocabulary_.items(), 20))
    
    # Check how many total n-grams we have
    # len(cvec.vocabulary_)
    
    # Initialize the vectorizer with new settings and check the new vocabulary length
    cvec = CountVectorizer(stop_words='english', min_df=.0025, max_df=.1, ngram_range=(1,2))
    cvec.fit(df_n.stemmed)
    #len(cvec.vocabulary_)

    # transform the document into a “bag of words” representation
    cvec_counts = cvec.transform(df_n.stemmed)
    # print('sparse matrix shape:', cvec_counts.shape)
    # print('nonzero count:', cvec_counts.nnz)
    # print('sparsity: %.2f%%' % (100.0 * cvec_counts.nnz / (cvec_counts.shape[0] * cvec_counts.shape[1])))
    
    # Let’s look at the top 20 most common terms
    occ = np.asarray(cvec_counts.sum(axis=0)).ravel().tolist()
    counts_df = pd.DataFrame({'term': cvec.get_feature_names(), 'occurrences': occ})
    top_n_df = counts_df.sort_values(by='occurrences', ascending=False).head(20)
    
    return top_n_df

# %%
for df_name, df in translated_dfs_dict.items():
    df_name_new = df_name + "_top_n_df"
    exec(df_name_new + ' = top_n_words(df)')
# Out:
#                ID                                              tweet  \
# 0  am_train_00001   Tesfaye, you posted a picture of a professor ...
# 1  am_train_00002    This is the corner of your knowledge, isn't it?
# 2  am_train_00003   Is it called a report? If there is anything e...
# 3  am_train_00004   ?? It reminded me of what we used to do in th...
# 4  am_train_00005                    Is it clear?? ???? He recovered
#
#        label
# 0   negative
# 1   negative
# 2   negative
# 3   negative
# 4   negative
#                 ID                                              tweet  \
# 0   dz_train_00001   @user According to your site, you seem to hav...
# 1   dz_train_00002                                 @user it's amazing
# 2   dz_train_00003                               @user it's hilarious
# 3   dz_train_00004  @user @user You are afraid to answer Nasser in...
# 4   dz_train_00005   @user mrnka I swear to God 😂😂😂 Depression aft...
#
#       label
# 0  negative
# 1  negative
# 2  negative
# 3  negative
# 4  negative
#                 ID                                              tweet  \
# 0   ha_train_00001   @user With the money of the North, there is n...
# 1   ha_train_00002   @user Do you have any Adu ar Banda 💔😭 he is t...
# 2   ha_train_00003   @user Be patient, madrid, you have many chanc...
# 3   ha_train_00004  @user Hmmm now you are below the greatness of ...
# 4   ha_train_00005   @user @user The Nigerian governors are sellin...
#
#        label
# 0   negative
# 1   negative
# 2   negative
# 3   negative
# 4   negative
#                ID                                              tweet  \
# 0  ig_train_00001      Father Ike Dig ooo. 😂 https://t.co/NDS7juFBGd
# 1  ig_train_00002                       @user God father how long???
# 2  ig_train_00003   Lol. Your head is beautiful too.. 😐😒😒😒 https:...
# 3  ig_train_00004   @user lol. Fulani herdsmen. Please retweet. E...
# 4  ig_train_00005   The ghetto father is in your body please!!! h...
#
#        label
# 0   negative
# 1   negative
# 2   negative
# 3   negative
# 4   negative
#                 ID                                              tweet  \
# 0   my_train_00001  hhhhhhhhhhhhhhhhhhhhh ana ga3ma sma3tt ach kan...
# 1   my_train_00002   hhhh hardart jomhorha la fi3lan kadahko lach ...
# 2   my_train_00003   : I understand Othmani and the popular debate...
# 3   my_train_00004                        He was the best Arab ruler.
# 4   my_train_00005   Mariano Rajoy: In particular, Morocco and Spa...
#
#        label
# 0    neutral
# 1    neutral
# 2    neutral
# 3   positive
# 4    neutral
#                 ID                                              tweet  \
# 0  pcm_train_00001  yeah ‍️the guy wants to trend dat was why e jo...
# 1  pcm_train_00002  this life is so funny sef you will work hard a...
# 2  pcm_train_00003  dis is unfair of urcompany goingtowks nw ive b...
# 3  pcm_train_00004  lil wayne don vex me im actually not excited a...
# 4  pcm_train_00005  dis is unfair of ur company going to wks nw iv...
#
#       label
# 0  negative
# 1  negative
# 2  negative
# 3  negative
# 4  negative
#                ID                                              tweet  \
# 0  pt_train_00001   I asked God for an answer, he gave it to me. ...
# 1  pt_train_00002   I just wish I could go back in time and do it...
# 2  pt_train_00003   @user This type is executable! Much worse tha...
# 3  pt_train_00004   There are guys that just you cross the road 🛣...
# 4  pt_train_00005   These guys from Yababuluko have a lot of nois...
#
#        label
# 0   negative
# 1   negative
# 2   negative
# 3   negative
# 4   negative
#                ID                                              tweet  \
# 0  sw_train_00001  Because Tanesco is deliberately cutting off el...
# 1  sw_train_00002   I have never seen any content other than that...
# 2  sw_train_00003   A bomb planted in a car targeting Turkish bui...
# 3  sw_train_00004   There is a video circulating on the internet ...
# 4  sw_train_00005   The caterpillars go through 6 main growth sta...
#
#        label
# 0   negative
# 1   negative
# 2   negative
# 3   negative
# 4   negative
#                ID                                              tweet  \
# 0  yo_train_00001  You black-headed death, you didn't do it. You ...
# 1  yo_train_00002       Yoruba keeps crying """"""". :) #ebu #Yoruba
# 2  yo_train_00003   The highest proverb had "" "" "" "" "" "" "" ...
# 3  yo_train_00004   RT @user: @user the culture of people who don...
# 4  yo_train_00005   RT @user: I see each and every one of them. A...
#
#        label
# 0   negative
# 1   negative
# 2   negative
# 3   negative
# 4   negative

# %%
for df_name, df in raw_dfs_dict.items():
    df_name_new = df_name + "_top_n_df"
    exec(df_name_new + ' = top_n_words(df)')
# Out:
#                ID                                              tweet     label
# 0  am_train_00001  Tesfaye ለካስ ጭብል ለብሰሽ የፕሮፌሰርን ፎቶ ለጥፈክ እልም ያልክ ባ...  negative
# 1  am_train_00002  ይሄው ነው አይደል የእውቀትሽ ጥግ....በሰሚ ሰሚ ከምትናገሪ ለምን ታሪክ...  negative
# 2  am_train_00003                ዘገበ ይባላል? ሌላ የሚባል ነገር ካለ አንተዉ ንገረን!  negative
# 3  am_train_00004  ?? ድሮ በዘመነ ኮዳክ ፎቶ ቤት ፍላሹ ፏ ሲል አይናችን ተጨፍኖ እንዳይወ...  negative
# 4  am_train_00005                                     ዠልጥ?? ???? ገገማ  negative
#                ID                                              tweet     label
# 0  dz_train_00001  @user على حسب موقعك يبدو أنك صاحب نظرة ثاقبة ....  negative
# 1  dz_train_00002                                  @user تبهليل هاذا  negative
# 2  dz_train_00003                       @user هاذي تبهليل ماشي فهامة  negative
# 3  dz_train_00004  @user @user تخاف نجاوب يا ناصر ببلوك لانو طريق...  negative
# 4  dz_train_00005  @user مرنكة أقسم بالله 😂😂😂تبهليل ما بعد منتصف ...  negative
#                ID                                              tweet     label
# 0  ha_train_00001  @user Da kudin da Arewa babu wani abin azo aga...  negative
# 1  ha_train_00002  @user Kaga wani Adu ar Banda💔😭 wai a haka Shi ...  negative
# 2  ha_train_00003  @user Sai haquri fa yan madrid daman kunce cha...  negative
# 3  ha_train_00004  @user Hmmm yanzu kai kasan girman allah daxaka...  negative
# 4  ha_train_00005  @user @user Wai gwamno nin Nigeria suna afa kw...  negative
#                ID                                              tweet     label
# 0  ig_train_00001       Nna Ike Gwuru ooo. 😂 https://t.co/NDS7juFBGd  negative
# 1  ig_train_00002                 @user Chineke nna kezi mgbe ole???  negative
# 2  ig_train_00003  Lol. Isi adirokwanu gi nma.. 😐😒😒😒 https://t.co...  negative
# 3  ig_train_00004  @user haha. Fulani herdsmen. akpa amu gi retwe...  negative
# 4  ig_train_00005  Nna ghetto di gi na aru biko!!! https://t.co/4...  negative
#                ID                                              tweet     label
# 0  ma_train_00001  hhhhhhhhhhhhhhhhhhhhhh ana ga3ma sma3tt ach ka...   neutral
# 1  ma_train_00002  hhhh hardart jomhorha la fi3lan kadahko lach m...   neutral
# 2  ma_train_00003  : أتفهم العثماني وأتفهم الجدل الشعبي. الحل: حا...   neutral
# 3  ma_train_00004                                كان افظل حاكم عربي'  positive
# 4  ma_train_00005  ماريانو راخوي : خاص المغرب واسبانيا يشرحو للرأ...   neutral
#                 ID                                              tweet  \
# 0  pcm_train_00001  yeah ‍️the guy wants to trend dat was why e jo...
# 1  pcm_train_00002  this life is so funny sef you will work hard a...
# 2  pcm_train_00003  dis is unfair of urcompany goingtowks nw ive b...
# 3  pcm_train_00004  lil wayne don vex me im actually not excited a...
# 4  pcm_train_00005  dis is unfair of ur company going to wks nw iv...
#
#       label
# 0  negative
# 1  negative
# 2  negative
# 3  negative
# 4  negative
#                ID                                              tweet     label
# 0  pt_train_00001  Pedi uma resposta a Deus, ele deu me. Estou mu...  negative
# 1  pt_train_00002  Só queria poder voltar no tempo e fazer difere...  negative
# 2  pt_train_00003  @user Este tipo é execrável! Muito pior que pa...  negative
# 3  pt_train_00004  Tem gajos que só de você atravessar estrada 🛣,...  negative
# 4  pt_train_00005  Esses gajos de Yababuluko têm mng barulho nos ...  negative
#                ID                                              tweet     label
# 0  sw_train_00001  Kwani tanesco wanakataga umeme makusudinadhani...  negative
# 1  sw_train_00002  cjawahi kuona content yoyote zaidi ya kuwa ana...  negative
# 2  sw_train_00003  Bomu lililokuwa limetegwa ndani ya gari likiwa...  negative
# 3  sw_train_00004  Kuna video inasambaa mitandaoni jamaa amemfuma...  negative
# 4  sw_train_00005  Viwavijeshi wanapita katika hatua kuu 6 za uku...  negative
#                ID                                              tweet     label
# 0  yo_train_00001  Ìwọ ikú òpònú abaradúdú wọ, o ò ṣe é 're o. O ...  negative
# 1  yo_train_00002  Yorùbá nbú'yàn ṣá """"""""..àyà wanle bí òkú ì...  negative
# 2  yo_train_00003  Òwe àgbà ní """"""""ọmọlọ́mọ là á rán níṣẹ́ à ...  negative
# 3  yo_train_00004  RT @user: @user asa kasa ti awon eyan ko ni od...  negative
# 4  yo_train_00005  RT @user: Mo ń rí àwọn èébú kọ̀ọ̀kan. Àti àwọn...  negative

# %%
print(df_am_eng_top_n_df.head())
print(df_dz_eng_top_n_df.head())
print(df_ha_eng_top_n_df.head())
print(df_ig_eng_top_n_df.head())
print(df_ma_eng_top_n_df.head())
print(df_pcm_eng_top_n_df.head())
print(df_pt_eng_top_n_df.head())
print(df_sw_eng_top_n_df.head())
print(df_yo_eng_top_n_df.head())
# Out:
#          term  occurrences
# 511     peopl          464
# 611       say          455
# 207       don          406
# 238  ethiopia          342
# 604      said          341
#      term  occurrences
# 93    don          176
# 130   god          175
# 322  said          102
# 192  know           91
# 324   say           89
#           term  occurrences
# 39       bless         1430
# 131  god bless         1255
# 90         don          971
# 6        allah          776
# 203       know          659
#       term  occurrences
# 118    god         1144
# 123   good         1107
# 249  peopl          599
# 155   igbo          568
# 35   bless          558
#          term  occurrences
# 31         al          378
# 359        li          375
# 42        ana          367
# 434   morocco          270
# 432  moroccan          254
#      term  occurrences
# 330   fit          509
# 748   sef          500
# 0    abeg          490
# 146  come          456
# 927   wan          446
#      term  occurrences
# 163   don          272
# 234   god          249
# 320  like          205
# 237  good          179
# 606  want          176
#       term  occurrences
# 798  thank          158
# 581  peopl          131
# 460   like          129
# 434   know          126
# 840   veri          125
#      term  occurrences
# 243  good          992
# 139   day          643
# 237   god          589
# 156   don          582
# 326  know          577

# %% [markdown]
# ## Preprocessing

# %%
# !pip install nltk
# Out:
# Requirement already satisfied: nltk in c:\users\aisha\anaconda3\lib\site-packages (3.2.4)
# Requirement already satisfied: six in c:\users\aisha\anaconda3\lib\site-packages (from nltk) (1.15.0)

# %%
import nltk
from nltk.corpus import stopwords
# print(stopwords.words('english'))

# %%
# FUNCTIONS TO REMOVE EMOJIS / PUNCTUATION CHARACTERS / WORDS WITH LENGTH LESS THAN 3 / BANNED WORDS:

import re

def remove_emojis(data):
    emoj = re.compile("["
        u"\U0001F600-\U0001F64F"  # emoticons
        u"\U0001F300-\U0001F5FF"  # symbols & pictographs
        u"\U0001F680-\U0001F6FF"  # transport & map symbols
        u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
        u"\U00002500-\U00002BEF"  # chinese char
        u"\U00002702-\U000027B0"
        u"\U00002702-\U000027B0"
        u"\U000024C2-\U0001F251"
        u"\U0001f926-\U0001f937"
        u"\U00010000-\U0010ffff"
        u"\u2640-\u2642" 
        u"\u2600-\u2B55"
        u"\u200d"
        u"\u23cf"
        u"\u23e9"
        u"\u231a"
        u"\ufe0f"  # dingbats
        u"\u3030"
                      "]+", re.UNICODE)
    return re.sub(emoj, '', data)


def remove_puncs(item):
    punc = '''!()-[]{};:'"\,<>./?@#$%^&*_~1234567890‹“…‘—’”'''
    for char in item:
        if char in punc:
            item = item.replace(char, "")
    return item

#re.sub(r'\b\w{1,3}\b', '', c)

def remove_less_three_char(item):
    if len(item) >= 3:
        return item
    else:
        return ""

banned = ['ourselves', 'hers', 'between', 'yourself', 'but', 'again', 'there', 'about', 'once', 'during', 'out', 'very', 
          'having', 'with', 'they', 'own', 'an', 'be', 'some', 'for', 'do', 'its', 'yours', 'such', 'into', 'of', 'most',
          'itself', 'other', 'off', 'is', 's', 'am', 'or', 'who', 'as', 'from', 'him', 'each', 'the', 'themselves', 'until',
          'below', 'are', 'we', 'these', 'your', 'his', 'through', 'don', 'nor', 'me', 'were', 'her', 'more', 'himself', 
          'this', 'down', 'should', 'our', 'their', 'while', 'above', 'both', 'up', 'to', 'ours', 'had', 'she', 'all', 'no', 
          'when', 'at', 'any', 'before', 'them', 'same', 'and', 'been', 'have', 'in', 'will', 'on', 'does', 'yourselves', 
          'then', 'that', 'because', 'what', 'over', 'why', 'so', 'can', 'did', 'not', 'now', 'under', 'he', 'you', 'herself',
          'has', 'just', 'where', 'too', 'only', 'myself', 'which', 'those', 'i', 'after', 'few', 'whom', 't', 'being', 'if', 
          'theirs', 'my', 'against', 'a', 'by', 'doing', 'it', 'how', 'further', 'was', 'here', 'than', 'user']
# banned = ['@user', '@user:'] # add stopped words here

# %%
## Preprocessing 

def preprocessing(df):

    df_translated_combined_new = df #df_translated_combined #df_raw_combined

    #Create list
    df_translated_combined_new['words'] = df_translated_combined_new.tweet.str.lower().str.split()
    # remove emojis
    df_translated_combined_new["words"] = [[remove_emojis(item) for item in x] for x in df_translated_combined_new["words"]]
    # remove punctuations
    df_translated_combined_new["words"] = [[remove_puncs(item) for item in x] for x in df_translated_combined_new["words"]]
    # remove words from banned list (including user + stopwords)
    df_translated_combined_new["words"] = [[item for item in x if item not in banned] for x in df_translated_combined_new["words"]]
    # remove stopwords
    # df_translated_combined_new["words"] = [[item for item in x if item not in stopwords.words('english')] for x in df_translated_combined_new["words"]]
    # remove words shorter than length 3
    df_translated_combined_new["words"] = [[remove_less_three_char(item) for item in x] for x in df_translated_combined_new["words"]]
    # remove empty strings from list
    df_translated_combined_new["words"] = [[item for item in x if item] for x in df_translated_combined_new["words"]]
    
    return df_translated_combined_new

# %% [markdown]
# ### Top N occurances using MultiLabelBinarizer

# %%
from sklearn.preprocessing import MultiLabelBinarizer

def top_n_mb(df):

    df = preprocessing(df)
    s = df['words']

    mlb = MultiLabelBinarizer()
    mlb.fit(s)
    out = pd.DataFrame(mlb.transform(s),columns=mlb.classes_).groupby(df['label']).sum().replace(0,np.nan).stack().astype(int).sort_values(ascending=False)
    # out.replace(0,np.nan).stack().astype(int).sort_values(ascending=False)
    # out.sort_values(ascending=False)
    return out

# %%
print("*** English: ***")
for df_name, df in translated_dfs_dict.items():
    df_name_new = df_name + "_top_n_mb"
    exec(df_name_new + ' = top_n_mb(df)')
    print("\n",df_name.split("_")[1],":\n")
    exec("print(" + df_name_new + ".head())")
    
print("\n*** African: ***")    
for df_name, df in raw_dfs_dict.items():
    df_name_new = df_name + "_top_n_mb"
    exec(df_name_new + ' = top_n_mb(df)')
    print("\n",df_name.split("_")[1],":\n")
    exec("print(" + df_name_new + ".head())")
# Out:
# *** English: ***
#
#  am :
#
# label
#  neutral   the     1949
#            and     1090
#  negative  the      885
#  neutral   that     746
#  positive  the      741
# dtype: int32
#
#  dz :
#
# label
# negative  and    393
#           the    357
#           you    284
# positive  the    154
#           you    151
# dtype: int32
#
#  ha :
#
# label
#  positive  god    2489
#  negative  the    1977
#  positive  the    1657
#  neutral   the    1495
#  positive  you    1372
# dtype: int32
#
#  ig :
#
# label
#  neutral   the    1425
#  positive  you    1116
#  neutral   you    1014
#            and     817
#  positive  god     738
# dtype: int32
#
#  ma :
#
# label
#  neutral   the    841
#  negative  the    825
#            and    648
#  neutral   and    624
#  positive  the    620
# dtype: int32
#
#  pcm :
#
# label
# negative  dey     1888
# positive  dey     1061
# negative  for      942
#           like     928
#           the      843
# dtype: int32
#
#  pt :
#
# label
#  neutral   the     738
#            and     433
#  negative  the     330
#  neutral   you     316
#            that    289
# dtype: int32
#
#  sw :
#
# label
#  neutral   the    650
#            and    370
#  positive  the    350
#  neutral   you    344
#            for    269
# dtype: int32
#
#  yo :
#
# label
#  positive  the       1947
#  neutral   the       1829
#            yoruba    1412
#  negative  the       1211
#  positive  you       1034
# dtype: int32
#
# *** African: ***
#
#  am :
#
# label
# neutral  ነው።    177
#          ነገር    157
#          ነበር    124
#          አሁን    110
#          ውስጥ    109
# dtype: int32
#
#  dz :
#
# label
# negative  علابالي    86
# positive  علابالي    70
# negative  على        68
# positive  مزية       68
# negative  وعلاه      60
# dtype: int32
#
#  ha :
#
# label
# positive  allah     2931
# negative  allah      645
#           wannan     506
# positive  wannan     491
# negative  sai        477
# dtype: int32
#
#  ig :
#
# label
# neutral   onye      849
# positive  chukwu    580
#           onye      523
# neutral   nke       433
#           ndi       413
# dtype: int32
#
#  ma :
#
# label
# positive  الله    251
# neutral   على     217
# negative  على     190
# neutral   ana     182
# negative  الله    178
# dtype: int32
#
#  pcm :
#
# label
# negative  dey     1952
# positive  dey     1076
# negative  for      944
#           like     930
#           the      834
# dtype: int32
#
#  pt :
#
# label
# neutral   que     522
#           não     377
# negative  que     289
#           não     282
# neutral   para    273
# dtype: int32
#
#  sw :
#
# label
# neutral   kwa       326
# positive  kwa       229
# neutral   kwenye    105
#           kama      104
#           yako       82
# dtype: int32
#
#  yo :
#
# label
# neutral   yoruba    1300
# positive  yoruba     768
# negative  yoruba     493
# neutral   àwọn       455
#           ibeere     434
# dtype: int32

# %% [markdown]
# ### Top N Count

# %%
def top_n_count(df_dict):
    
    for df_name, df in df_dict.items():
        df = preprocessing(df)
        # print(df)
        # top_n_df = df.explode('words').groupby(['language','label'])['words'].value_counts().reset_index(name='count')
        top_n_df = df.explode('words').groupby('label')['words'].value_counts().reset_index(name='count')
        df_name_new = df_name + "_top_n_count"
        exec(df_name_new + ' = top_n_df')
        print("\n",df_name.split("_")[1],":\n")
        exec("print(" + df_name_new + ".head())")
    
    return None
    
print("*** English: ***")    
top_n_count(translated_dfs_dict)
print("\n*** African: ***")
top_n_count(raw_dfs_dict)
# Out:
# *** English: ***
#
#  am :
#
#        label words  count
# 0   negative   the   1842
# 1   negative   and    714
# 2   negative   you    681
# 3   negative  that    481
# 4   negative   are    395
#
#  dz :
#
#       label words  count
# 0  negative   the    603
# 1  negative   and    553
# 2  negative   you    415
# 3  negative   are    142
# 4  negative  they    136
#
#  ha :
#
#        label words  count
# 0   negative   the   3456
# 1   negative   you   1871
# 2   negative   and   1394
# 3   negative   are   1302
# 4   negative   not    805
#
#  ig :
#
#        label words  count
# 0   negative   the    740
# 1   negative   you    638
# 2   negative   are    312
# 3   negative   and    300
# 4   negative  your    270
#
#  ma :
#
#        label words  count
# 0   negative   the   1858
# 1   negative   and   1054
# 2   negative   you    383
# 3   negative   are    271
# 4   negative   god    263
#
#  pcm :
#
#       label words  count
# 0  negative   dey   2712
# 1  negative   you   1263
# 2  negative   for   1156
# 3  negative   the   1136
# 4  negative  like   1024
#
#  pt :
#
#        label words  count
# 0   negative   the    532
# 1   negative   and    271
# 2   negative   you    259
# 3   negative  this    179
# 4   negative  that    171
#
#  sw :
#
#        label words  count
# 0   negative   the    267
# 1   negative   and     78
# 2   negative   you     70
# 3   negative  that     58
# 4   negative   are     57
#
#  yo :
#
#        label   words  count
# 0   negative     the   2652
# 1   negative    that    599
# 2   negative     not    573
# 3   negative  yoruba    568
# 4   negative    they    479
#
# *** African: ***
#
#  am :
#
#       label  words  count
# 0  negative    ነው።    112
# 1  negative    ነገር     77
# 2  negative    ህዝብ     72
# 3  negative  አይደለም     67
# 4  negative    ውስጥ     66
#
#  dz :
#
#       label    words  count
# 0  negative  علابالي     87
# 1  negative      على     71
# 2  negative    وعلاه     62
# 3  negative     بزاف     60
# 4  negative      انا     50
#
#  ha :
#
#       label   words  count
# 0  negative   allah    820
# 1  negative  wannan    567
# 2  negative     sai    522
# 3  negative    kuma    475
# 4  negative     dan    442
#
#  ig :
#
#       label words  count
# 0  negative  onye    421
# 1  negative   ndi    346
# 2  negative   ike    252
# 3  negative   ara    219
# 4  negative   ihe    152
#
#  ma :
#
#       label words  count
# 0  negative   على    209
# 1  negative  الله    204
# 2  negative   هذا     80
# 3  negative   chi     72
# 4  negative   ana     68
#
#  pcm :
#
#       label words  count
# 0  negative   dey   2810
# 1  negative   you   1237
# 2  negative   for   1161
# 3  negative   the   1120
# 4  negative  like   1026
#
#  pt :
#
#       label words  count
# 0  negative   que    412
# 1  negative   não    352
# 2  negative  para    137
# 3  negative   com    111
# 4  negative   por     98
#
#  sw :
#
#       label   words  count
# 0  negative     kwa     60
# 1  negative    watu     22
# 2  negative    sana     21
# 3  negative     cha     20
# 4  negative  katika     20
#
#  yo :
#
#       label   words  count
# 0  negative  yoruba    517
# 1  negative    wọ́n    378
# 2  negative    àwọn    366
# 3  negative     wọn    212
# 4  negative     ọmọ    183

# %% [markdown]
# ## Top N by label

# %%
def top_n_by_label(df_dict,n):
    
    for df_name, df in df_dict.items():
        
        df = preprocessing(df)
        df = df.explode('words').groupby('label')['words'].value_counts().reset_index(name='count')
        df_top_n_by_label = df.groupby('label').head(n)  
        
        df_name_new = df_name + "_top_n_by_label"
        exec(df_name_new + ' = df_top_n_by_label')
        print("\n",df_name.split("_")[1],":\n")
        exec("print(" + df_name_new + ")")
    
    return None


n = 5 # top n words per label
print("*** English: ***")    
top_n_by_label(translated_dfs_dict,n)
print("\n*** African: ***")
top_n_by_label(raw_dfs_dict,n)
# Out:
# *** English: ***
#
#  am :
#
#            label words  count
# 0       negative   the   1842
# 1       negative   and    714
# 2       negative   you    681
# 3       negative  that    481
# 4       negative   are    395
# 4611     neutral   the   4125
# 4612     neutral   and   1437
# 4613     neutral   you   1074
# 4614     neutral  that    895
# 4615     neutral   not    609
# 11668   positive   the   1458
# 11669   positive   and    599
# 11670   positive   you    489
# 11671   positive   for    296
# 11672   positive  that    280
#
#  dz :
#
#          label words  count
# 0     negative   the    603
# 1     negative   and    553
# 2     negative   you    415
# 3     negative   are    142
# 4     negative  they    136
# 2689   neutral   and    151
# 2690   neutral   the    137
# 2691   neutral   you    107
# 2692   neutral  what     33
# 2693   neutral  dont     31
# 3701  positive   the    248
# 3702  positive   you    206
# 3703  positive   and    196
# 3704  positive   god     90
# 3705  positive   are     52
#
#  ha :
#
#            label words  count
# 0       negative   the   3456
# 1       negative   you   1871
# 2       negative   and   1394
# 3       negative   are   1302
# 4       negative   not    805
# 6366     neutral   the   2186
# 6367     neutral   you   1197
# 6368     neutral   and    837
# 6369     neutral   are    730
# 6370     neutral  will    570
# 12305   positive   god   3120
# 12306   positive   the   2549
# 12307   positive   you   1911
# 12308   positive   and   1437
# 12309   positive   may   1304
#
#  ig :
#
#            label words  count
# 0       negative   the    740
# 1       negative   you    638
# 2       negative   are    312
# 3       negative   and    300
# 4       negative  your    270
# 3833     neutral   the   2205
# 3834     neutral   you   1251
# 3835     neutral   and    983
# 3836     neutral   are    633
# 3837     neutral   who    548
# 11248   positive   you   1506
# 11249   positive   the   1058
# 11250   positive   god    858
# 11251   positive  good    814
# 11252   positive   and    532
#
#  ma :
#
#            label words  count
# 0       negative   the   1858
# 1       negative   and   1054
# 2       negative   you    383
# 3       negative   are    271
# 4       negative   god    263
# 7727     neutral   the   2434
# 7728     neutral   and    940
# 7729     neutral   for    292
# 7730     neutral   ana    200
# 7731     neutral  with    185
# 18077   positive   the   1230
# 18078   positive   and    843
# 18079   positive   you    586
# 18080   positive   god    381
# 18081   positive   for    250
#
#  pcm :
#
#          label words  count
# 0     negative   dey   2712
# 1     negative   you   1263
# 2     negative   for   1156
# 3     negative   the   1136
# 4     negative  like   1024
# 7852   neutral   dey     61
# 7853   neutral  like     33
# 7854   neutral   for     32
# 7855   neutral   the     31
# 7856   neutral   you     29
# 8590  positive   dey   1532
# 8591  positive   you    920
# 8592  positive   for    634
# 8593  positive   the    633
# 8594  positive   and    486
#
#  pt :
#
#           label words  count
# 0      negative   the    532
# 1      negative   and    271
# 2      negative   you    259
# 3      negative  this    179
# 4      negative  that    171
# 2966    neutral   the   1413
# 2967    neutral   and    585
# 2968    neutral   you    439
# 2969    neutral  that    350
# 2970    neutral  this    300
# 8029   positive   the    466
# 8030   positive   and    271
# 8031   positive   you    217
# 8032   positive   for    135
# 8033   positive  this    105
#
#  sw :
#
#           label words  count
# 0      negative   the    267
# 1      negative   and     78
# 2      negative   you     70
# 3      negative  that     58
# 4      negative   are     57
# 1385    neutral   the   1207
# 1386    neutral   you    547
# 1387    neutral   and    447
# 1388    neutral   for    344
# 1389    neutral  that    283
# 5262   positive   the    692
# 5263   positive   you    303
# 5264   positive   and    287
# 5265   positive   for    239
# 5266   positive  that    118
#
#  yo :
#
#            label   words  count
# 0       negative     the   2652
# 1       negative    that    599
# 2       negative     not    573
# 3       negative  yoruba    568
# 4       negative    they    479
# 6054     neutral     the   4257
# 6055     neutral  yoruba   1590
# 6056     neutral     and    813
# 6057     neutral    that    785
# 6058     neutral     you    599
# 14752   positive     the   4049
# 14753   positive     you   1502
# 14754   positive    will   1247
# 14755   positive  yoruba    926
# 14756   positive     and    910
#
# *** African: ***
#
#  am :
#
#           label  words  count
# 0      negative    ነው።    112
# 1      negative    ነገር     77
# 2      negative    ህዝብ     72
# 3      negative  አይደለም     67
# 4      negative    ውስጥ     66
# 10550   neutral    ነው።    191
# 10551   neutral    ነገር    171
# 10552   neutral    ነበር    127
# 10553   neutral    ውስጥ    116
# 10554   neutral    አሁን    113
# 29535  positive    ነው።    111
# 29536  positive   መልካም     92
# 29537  positive    ነገር     72
# 29538  positive    አሜን     72
# 29539  positive   እንኳን     72
#
#  dz :
#
#          label    words  count
# 0     negative  علابالي     87
# 1     negative      على     71
# 2     negative    وعلاه     62
# 3     negative     بزاف     60
# 4     negative      انا     50
# 4726   neutral  علابالي     55
# 4727   neutral    وقتاش     40
# 4728   neutral     زعما     33
# 4729   neutral    وعلاه     28
# 4730   neutral   واقيلا     24
# 6216  positive  علابالي     72
# 6217  positive     مزية     68
# 6218  positive     الله     52
# 6219  positive     بزاف     44
# 6220  positive      على     32
#
#  ha :
#
#           label   words  count
# 0      negative   allah    820
# 1      negative  wannan    567
# 2      negative     sai    522
# 3      negative    kuma    475
# 4      negative     dan    442
# 11604   neutral     sai    390
# 11605   neutral    kuma    378
# 11606   neutral  wannan    358
# 11607   neutral     dai    260
# 11608   neutral     dan    255
# 21130  positive   allah   3832
# 21131  positive  wannan    533
# 21132  positive    mana    437
# 21133  positive    kuma    428
# 21134  positive    yasa    363
#
#  ig :
#
#           label   words  count
# 0      negative    onye    421
# 1      negative     ndi    346
# 2      negative     ike    252
# 3      negative     ara    219
# 4      negative     ihe    152
# 5211    neutral    onye    926
# 5212    neutral     nke    482
# 5213    neutral     ndi    465
# 5214    neutral     ihe    415
# 5215    neutral    anyi    406
# 16073  positive    onye    634
# 16074  positive  chukwu    631
# 16075  positive     oma    420
# 16076  positive     mma    377
# 16077  positive     nke    279
#
#  ma :
#
#           label    words  count
# 0      negative      على    209
# 1      negative     الله    204
# 2      negative      هذا     80
# 3      negative      chi     72
# 4      negative      ana     68
# 11423   neutral      على    244
# 11424   neutral      ana    202
# 11425   neutral     ghir    132
# 11426   neutral     ديال    131
# 11427   neutral      rah    129
# 24059  positive     الله    290
# 24060  positive      على    140
# 24061  positive      ana     98
# 24062  positive  بنكيران     89
# 24063  positive      lik     79
#
#  pcm :
#
#          label words  count
# 0     negative   dey   2810
# 1     negative   you   1237
# 2     negative   for   1161
# 3     negative   the   1120
# 4     negative  like   1026
# 7858   neutral   dey     61
# 7859   neutral  like     33
# 7860   neutral   for     32
# 7861   neutral   the     31
# 7862   neutral   you     29
# 8596  positive   dey   1556
# 8597  positive   you    907
# 8598  positive   for    632
# 8599  positive   the    631
# 8600  positive   and    484
#
#  pt :
#
#          label  words  count
# 0     negative    que    412
# 1     negative    não    352
# 2     negative   para    137
# 3     negative    com    111
# 4     negative    por     98
# 3641   neutral    que    728
# 3642   neutral    não    462
# 3643   neutral   para    323
# 3644   neutral    com    212
# 3645   neutral   está    184
# 9877  positive    que    265
# 9878  positive   para    143
# 9879  positive    não    133
# 9880  positive    com     86
# 9881  positive  muito     69
#
#  sw :
#
#          label   words  count
# 0     negative     kwa     60
# 1     negative    watu     22
# 2     negative    sana     21
# 3     negative     cha     20
# 4     negative  katika     20
# 1768   neutral     kwa    427
# 1769   neutral  kwenye    116
# 1770   neutral    kama    111
# 1771   neutral    yako     92
# 1772   neutral    sana     87
# 7640  positive     kwa    300
# 7641  positive    sana     84
# 7642  positive  katika     67
# 7643  positive    yako     56
# 7644  positive     cha     50
#  yo :
#
#           label   words  count
# 0      negative  yoruba    517
# 1      negative    wọ́n    378
# 2      negative    àwọn    366
# 3      negative     wọn    212
# 4      negative     ọmọ    183
# 8775    neutral  yoruba   1389
# 8776    neutral    àwọn    603
# 8777    neutral    wọ́n    476
# 8778    neutral  ibeere    434
# 8779    neutral     àti    401
# 20642  positive  yoruba    809
# 20643  positive     ire    454
# 20644  positive  gbogbo    441
# 20645  positive     fún    378
# 20646  positive     ọmọ    338

# %% [markdown]
# ### Working with combined dataframes

# %%
df_translated_combined_new = preprocessing(df_translated_combined)
df_translated_combined_new
# Out:
#                    ID                                              tweet  \
# 0      am_train_00001   Tesfaye, you posted a picture of a professor ...
# 1      am_train_00002    This is the corner of your knowledge, isn't it?
# 2      am_train_00003   Is it called a report? If there is anything e...
# 3      am_train_00004   ?? It reminded me of what we used to do in th...
# 4      am_train_00005                    Is it clear?? ???? He recovered
# ...               ...                                                ...
# 56093  yo_train_08518   RT @user: The eyes of a bat are here, the eye...
# 56094  yo_train_08519   We are grateful to our opponents, we will be ...
# 56095  yo_train_08520  The person who was yesterday, who is today, ca...
# 56096  yo_train_08521                 My God is a miracle worker #yoruba
# 56097  yo_train_08522   RT @user: Come join me! #yorubafood #naijafoo...
#
#           label language                                              words
# 0      negative       am  [tesfaye, posted, picture, professor, wearing,...
# 1      negative       am                          [corner, knowledge, isnt]
# 2      negative       am        [called, report, anything, else, say, tell]
# 3      negative       am  [reminded, used, kodak, photo, booth, flash, w...
# 4      negative       am                                 [clear, recovered]
# ...         ...      ...                                                ...
# 56093  positive       yo  [eyes, bat, eyes, owl, seeing, anchors, today,...
# 56094  positive       yo  [grateful, opponents, wise, yes, know, trying,...
# 56095  positive       yo  [person, yesterday, today, cannot, tomorrow, w...
# 56096  positive       yo                     [god, miracle, worker, yoruba]
# 56097  positive       yo  [come, join, yorubafood, naijafood, africanfoo...
#
# [56098 rows x 5 columns]

# %%
# Explode and count

df_translated_combined_new1=df_translated_combined_new.explode('words').groupby('label')['words'].value_counts().reset_index(name='count')
df_translated_combined_new1
# Out:
#           label               words  count
# 0      negative                 dey   2743
# 1      negative                like   1760
# 2      negative              people   1642
# 3      negative                 god   1444
# 4      negative                dont   1314
# ...         ...                 ...    ...
# 80097  positive                 ዕድሜ      1
# 80098  positive  ធនាន្រ្រ្រ្រ្រ្រ្រ      1
# 80099  positive         ស្រ្រ្រ្រ្រ      1
# 80100  positive                 ọma      1
# 80101  positive               ​​​​​      1
#
# [80102 rows x 3 columns]

# %%
df_translated_combined_new_lang=df_translated_combined_new.explode('words').groupby(['language','label'])['words'].value_counts().reset_index(name='count')
df_translated_combined_new_lang
# Out:
#        language     label        words  count
# 0            am  negative       people    204
# 1            am  negative      country    119
# 2            am  negative         dont    118
# 3            am  negative         said     95
# 4            am  negative         like     94
# ...         ...       ...          ...    ...
# 130675       yo  positive       ósogbo      1
# 130676       yo  positive         ósun      1
# 130677       yo  positive          óyő      1
# 130678       yo  positive        úgúgû      1
# 130679       yo  positive  ស្រ្រ្រ្រ្រ      1
#
# [130680 rows x 4 columns]

# %%
df_translated_combined_new_lang2=df_translated_combined_new.explode('words').groupby('label')['words'].value_counts().reset_index(name='count')
df_translated_combined_new_lang2
# Out:
#           label               words  count
# 0      negative                 dey   2743
# 1      negative                like   1760
# 2      negative              people   1642
# 3      negative                 god   1444
# 4      negative                dont   1314
# ...         ...                 ...    ...
# 80097  positive                 ዕድሜ      1
# 80098  positive  ធនាន្រ្រ្រ្រ្រ្រ្រ      1
# 80099  positive         ស្រ្រ្រ្រ្រ      1
# 80100  positive                 ọma      1
# 80101  positive               ​​​​​      1
#
# [80102 rows x 3 columns]

# %%
df_translated_combined_new_lang3 = df_translated_combined_new_lang2.groupby('label').head(5)
df_translated_combined_new_lang3
# Out:
#           label   words  count
# 0      negative     dey   2743
# 1      negative    like   1760
# 2      negative  people   1642
# 3      negative     god   1444
# 4      negative    dont   1314
# 24848   neutral  yoruba   1595
# 24849   neutral    dont   1165
# 24850   neutral  people   1093
# 24851   neutral     one   1008
# 24852   neutral    know    966
# 56124  positive     god   5195
# 56125  positive    good   2519
# 56126  positive     may   1912
# 56127  positive   bless   1861
# 56128  positive     dey   1550

# %%
df_translated_combined_new2 = df_translated_combined_new.groupby('label')['label'].count()
df_translated_combined_new2
# Out:
# label
# negative    17363
# neutral     20879
# positive    17856
# Name: label, dtype: int64

# %%
df_translated_combined_new['label'].unique()
# Out:
# array(['negative', 'neutral', 'positive'], dtype=object)

# %%
df_translated_combined_new3 = df_translated_combined_new.groupby('label').size().plot(kind='bar',color=['#B81D13','#F7DB80','#008450'])
plt.xlabel('label')
plt.ylabel('count')
# Out:
# Text(0, 0.5, 'count')

# %%
sns.boxplot(x="label", y="text_len_initial", data=df_raw_combined_new, 
            palette=['#B81D13','#F7DB80','#008450'])


plt.title("Text Length across three labels")
plt.savefig("text_length.png")

# %%
df_translated_combined_new4 = df_translated_combined_new.groupby('label').head(5)
df_translated_combined_new4
# Out:
#                   ID                                              tweet  \
# 0     am_train_00001   Tesfaye, you posted a picture of a professor ...
# 1     am_train_00002    This is the corner of your knowledge, isn't it?
# 2     am_train_00003   Is it called a report? If there is anything e...
# 3     am_train_00004   ?? It reminded me of what we used to do in th...
# 4     am_train_00005                    Is it clear?? ???? He recovered
# 1548  am_train_01549                          Did I say something bad?!
# 1549  am_train_01550   A unique natural feature ***** East African w...
# 1550  am_train_01551  B/J Asamune Tsige and Deputy Prime Minister De...
# 1551  am_train_01552   ?? Okay, my brother, I will be planted. Who i...
# 1552  am_train_01553   It is knowing this that Dr. Abi became a Chri...
# 4652  am_train_04653                               I am good in Amharic
# 4653  am_train_04654   Prosperity Party, a protest rally with a seri...
# 4654  am_train_04655               The wise teacher of love, Teddy Afro
# 4655  am_train_04656   Amhara deserves a special benefit from the Ni...
# 4656  am_train_04657   Why should I be upset? I said don't talk abou...
#
#          label language                                              words
# 0     negative       am  [tesfaye, posted, picture, professor, wearing,...
# 1     negative       am                          [corner, knowledge, isnt]
# 2     negative       am        [called, report, anything, else, say, tell]
# 3     negative       am  [reminded, used, kodak, photo, booth, flash, w...
# 4     negative       am                                 [clear, recovered]
# 1548   neutral       am                              [say, something, bad]
# 1549   neutral       am  [unique, natural, feature, east, african, wate...
# 1550   neutral       am  [asamune, tsige, deputy, prime, minister, deme...
# 1551   neutral       am      [okay, brother, planted, love, much, sincere]
# 1552   neutral       am                  [knowing, abi, became, christian]
# 4652  positive       am                                    [good, amharic]
# 4653  positive       am  [prosperity, party, protest, rally, serious, m...
# 4654  positive       am                 [wise, teacher, love, teddy, afro]
# 4655  positive       am    [amhara, deserves, special, benefit, nile, dam]
# 4656  positive       am  [upset, said, dont, talk, rumours, didnt, say,...

# %%
# df_raw_combined_new = preprocessing(df_raw_combined)
df_raw_combined = merge_data_files(r'semeval2023-afrisenti-main/data/raw/train/', '_train.tsv')
df_raw_combined_new = df_raw_combined
df_raw_combined_new
# Out:
#                    ID                                              tweet  \
# 0      am_train_00001  Tesfaye ለካስ ጭብል ለብሰሽ የፕሮፌሰርን ፎቶ ለጥፈክ እልም ያልክ ባ...
# 1      am_train_00002  ይሄው ነው አይደል የእውቀትሽ ጥግ....በሰሚ ሰሚ ከምትናገሪ ለምን ታሪክ...
# 2      am_train_00003                ዘገበ ይባላል? ሌላ የሚባል ነገር ካለ አንተዉ ንገረን!
# 3      am_train_00004  ?? ድሮ በዘመነ ኮዳክ ፎቶ ቤት ፍላሹ ፏ ሲል አይናችን ተጨፍኖ እንዳይወ...
# 4      am_train_00005                                     ዠልጥ?? ???? ገገማ
# ...               ...                                                ...
# 56093  yo_train_08518  RT @user: Oju adan o'nribi, oju awodi o'nri or...
# 56094  yo_train_08519  a tú dúpẹ́ lọ́wọ́ àwọn alátakò wá náà, a ó gbọ...
# 56095  yo_train_08520  Ẹní tó làná, tó lòní, kò leè lọ̀la; Ọlọ́run nì...
# 56096  yo_train_08521  My God is """"""""onise iyanu"""""""" ( A Mira...
# 56097  yo_train_08522  RT @user: Ẹ wá ba mi re! #yorubafood #naijafoo...
#
#           label language
# 0      negative       am
# 1      negative       am
# 2      negative       am
# 3      negative       am
# 4      negative       am
# ...         ...      ...
# 56093  positive       yo
# 56094  positive       yo
# 56095  positive       yo
# 56096  positive       yo
# 56097  positive       yo
#
# [56098 rows x 4 columns]

# %%
df_raw_combined_new['text_len_initial'] = df_raw_combined.tweet.apply(lambda x:len(x))
df_raw_combined_new
# Out:
#                    ID                                              tweet  \
# 0      am_train_00001  Tesfaye ለካስ ጭብል ለብሰሽ የፕሮፌሰርን ፎቶ ለጥፈክ እልም ያልክ ባ...
# 1      am_train_00002  ይሄው ነው አይደል የእውቀትሽ ጥግ....በሰሚ ሰሚ ከምትናገሪ ለምን ታሪክ...
# 2      am_train_00003                ዘገበ ይባላል? ሌላ የሚባል ነገር ካለ አንተዉ ንገረን!
# 3      am_train_00004  ?? ድሮ በዘመነ ኮዳክ ፎቶ ቤት ፍላሹ ፏ ሲል አይናችን ተጨፍኖ እንዳይወ...
# 4      am_train_00005                                     ዠልጥ?? ???? ገገማ
# ...               ...                                                ...
# 56093  yo_train_08518  RT @user: Oju adan o'nribi, oju awodi o'nri or...
# 56094  yo_train_08519  a tú dúpẹ́ lọ́wọ́ àwọn alátakò wá náà, a ó gbọ...
# 56095  yo_train_08520  Ẹní tó làná, tó lòní, kò leè lọ̀la; Ọlọ́run nì...
# 56096  yo_train_08521  My God is """"""""onise iyanu"""""""" ( A Mira...
# 56097  yo_train_08522  RT @user: Ẹ wá ba mi re! #yorubafood #naijafoo...
#
#           label language  text_len_initial
# 0      negative       am                58
# 1      negative       am                70
# 2      negative       am                35
# 3      negative       am               113
# 4      negative       am                14
# ...         ...      ...               ...
# 56093  positive       yo               123
# 56094  positive       yo               202
# 56095  positive       yo               274
# 56096  positive       yo                65
# 56097  positive       yo                83
#
# [56098 rows x 5 columns]

# %%
df_raw_combined_new['words'] = df_raw_combined_new.tweet.str.lower().str.split()
df_raw_combined_new
# Out:
#                    ID                                              tweet  \
# 0      am_train_00001  Tesfaye ለካስ ጭብል ለብሰሽ የፕሮፌሰርን ፎቶ ለጥፈክ እልም ያልክ ባ...
# 1      am_train_00002  ይሄው ነው አይደል የእውቀትሽ ጥግ....በሰሚ ሰሚ ከምትናገሪ ለምን ታሪክ...
# 2      am_train_00003                ዘገበ ይባላል? ሌላ የሚባል ነገር ካለ አንተዉ ንገረን!
# 3      am_train_00004  ?? ድሮ በዘመነ ኮዳክ ፎቶ ቤት ፍላሹ ፏ ሲል አይናችን ተጨፍኖ እንዳይወ...
# 4      am_train_00005                                     ዠልጥ?? ???? ገገማ
# ...               ...                                                ...
# 56093  yo_train_08518  RT @user: Oju adan o'nribi, oju awodi o'nri or...
# 56094  yo_train_08519  a tú dúpẹ́ lọ́wọ́ àwọn alátakò wá náà, a ó gbọ...
# 56095  yo_train_08520  Ẹní tó làná, tó lòní, kò leè lọ̀la; Ọlọ́run nì...
# 56096  yo_train_08521  My God is """"""""onise iyanu"""""""" ( A Mira...
# 56097  yo_train_08522  RT @user: Ẹ wá ba mi re! #yorubafood #naijafoo...
#
#           label language  text_len_initial  \
# 0      negative       am                58
# 1      negative       am                70
# 2      negative       am                35
# 3      negative       am               113
# 4      negative       am                14
# ...         ...      ...               ...
# 56093  positive       yo               123
# 56094  positive       yo               202
# 56095  positive       yo               274
# 56096  positive       yo                65
# 56097  positive       yo                83
#
#                                                    words
# 0      [tesfaye, ለካስ, ጭብል, ለብሰሽ, የፕሮፌሰርን, ፎቶ, ለጥፈክ, እ...
# 1      [ይሄው, ነው, አይደል, የእውቀትሽ, ጥግ....በሰሚ, ሰሚ, ከምትናገሪ,...
# 2           [ዘገበ, ይባላል?, ሌላ, የሚባል, ነገር, ካለ, አንተዉ, ንገረን!]
# 3      [??, ድሮ, በዘመነ, ኮዳክ, ፎቶ, ቤት, ፍላሹ, ፏ, ሲል, አይናችን,...
# 4                                     [ዠልጥ??, ????, ገገማ]
# ...                                                  ...
# 56093  [rt, @user:, oju, adan, o'nribi,, oju, awodi, ...
# 56094  [a, tú, dúpẹ́, lọ́wọ́, àwọn, alátakò, wá, náà,...
# 56095  [ẹní, tó, làná,, tó, lòní,, kò, leè, lọ̀la;, ọ...
# 56096  [my, god, is, """"""""onise, iyanu"""""""", (,...
# 56097  [rt, @user:, ẹ, wá, ba, mi, re!, #yorubafood, ...
#
# [56098 rows x 6 columns]

# %%
df_raw_combined_new_sorted = df_raw_combined_new.sort_values(by='text_len_initial', ascending=False)
df_raw_combined_new_sorted
# Out:
#                    ID                                              tweet  \
# 33350  ma_train_01352  عندما كان المغربي يجاهد لتحرير ارضه في الصحراء...
# 35585  ma_train_03587  كلما في الامر هو ان بن كيران رجل صالح وادى الا...
# 35020  ma_train_03022  وثائق من المحكمة الأوروبية تدين الجمهورية الإي...
# 33891  ma_train_01893  نحن لا نتكلم من منطق عنصري و لكن ضاق بنا الحال...
# 34410  ma_train_02412  تحية احترام للسياسي و المناضل و من يقول الحق و...
# ...               ...                                                ...
# 2940   am_train_02941                                                 ሰው
# 4345   am_train_04346                                                 ነፃ
# 5629   am_train_05630                                                 ውብ
# 5061   am_train_05062                                                 ጥሩ
# 5830   am_train_05831                                                  ፐ
#
#           label language  text_len_initial  \
# 33350  positive       ma               771
# 35585  positive       ma               510
# 35020  negative       ma               444
# 33891  negative       ma               441
# 34410  positive       ma               437
# ...         ...      ...               ...
# 2940    neutral       am                 2
# 4345    neutral       am                 2
# 5629   positive       am                 2
# 5061   positive       am                 2
# 5830   positive       am                 1
#
#                                                    words
# 33350  [عندما, كان, المغربي, يجاهد, لتحرير, ارضه, في,...
# 35585  [كلما, في, الامر, هو, ان, بن, كيران, رجل, صالح...
# 35020  [وثائق, من, المحكمة, الأوروبية, تدين, الجمهوري...
# 33891  [نحن, لا, نتكلم, من, منطق, عنصري, و, لكن, ضاق,...
# 34410  [تحية, احترام, للسياسي, و, المناضل, و, من, يقو...
# ...                                                  ...
# 2940                                                [ሰው]
# 4345                                                [ነፃ]
# 5629                                                [ውብ]
# 5061                                                [ጥሩ]
# 5830                                                 [ፐ]
#
# [56098 rows x 6 columns]

# %%
df_raw_combined_new["num_words"] = [len(x) for x in df_translated_combined_new["words"]]
df_raw_combined_new
# Out:
#                    ID                                              tweet  \
# 0      am_train_00001  Tesfaye ለካስ ጭብል ለብሰሽ የፕሮፌሰርን ፎቶ ለጥፈክ እልም ያልክ ባ...
# 1      am_train_00002  ይሄው ነው አይደል የእውቀትሽ ጥግ....በሰሚ ሰሚ ከምትናገሪ ለምን ታሪክ...
# 2      am_train_00003                ዘገበ ይባላል? ሌላ የሚባል ነገር ካለ አንተዉ ንገረን!
# 3      am_train_00004  ?? ድሮ በዘመነ ኮዳክ ፎቶ ቤት ፍላሹ ፏ ሲል አይናችን ተጨፍኖ እንዳይወ...
# 4      am_train_00005                                     ዠልጥ?? ???? ገገማ
# ...               ...                                                ...
# 56093  yo_train_08518  RT @user: Oju adan o'nribi, oju awodi o'nri or...
# 56094  yo_train_08519  a tú dúpẹ́ lọ́wọ́ àwọn alátakò wá náà, a ó gbọ...
# 56095  yo_train_08520  Ẹní tó làná, tó lòní, kò leè lọ̀la; Ọlọ́run nì...
# 56096  yo_train_08521  My God is """"""""onise iyanu"""""""" ( A Mira...
# 56097  yo_train_08522  RT @user: Ẹ wá ba mi re! #yorubafood #naijafoo...
#
#           label language  text_len_initial  \
# 0      negative       am                58
# 1      negative       am                70
# 2      negative       am                35
# 3      negative       am               113
# 4      negative       am                14
# ...         ...      ...               ...
# 56093  positive       yo               123
# 56094  positive       yo               202
# 56095  positive       yo               274
# 56096  positive       yo                65
# 56097  positive       yo                83
#
#                                                    words  num_words
# 0      [tesfaye, ለካስ, ጭብል, ለብሰሽ, የፕሮፌሰርን, ፎቶ, ለጥፈክ, እ...          7
# 1      [ይሄው, ነው, አይደል, የእውቀትሽ, ጥግ....በሰሚ, ሰሚ, ከምትናገሪ,...          3
# 2           [ዘገበ, ይባላል?, ሌላ, የሚባል, ነገር, ካለ, አንተዉ, ንገረን!]          6
# 3      [??, ድሮ, በዘመነ, ኮዳክ, ፎቶ, ቤት, ፍላሹ, ፏ, ሲል, አይናችን,...         12
# 4                                     [ዠልጥ??, ????, ገገማ]          2
# ...                                                  ...        ...
# 56093  [rt, @user:, oju, adan, o'nribi,, oju, awodi, ...         15
# 56094  [a, tú, dúpẹ́, lọ́wọ́, àwọn, alátakò, wá, náà,...         13
# 56095  [ẹní, tó, làná,, tó, lòní,, kò, leè, lọ̀la;, ọ...         29
# 56096  [my, god, is, """"""""onise, iyanu"""""""", (,...          4
# 56097  [rt, @user:, ẹ, wá, ba, mi, re!, #yorubafood, ...          6
#
# [56098 rows x 7 columns]

# %%
df_raw_combined_new_sorted2 = df_raw_combined_new.sort_values(by='num_words', ascending=False)
df_raw_combined_new_sorted2
# Out:
#                    ID                                              tweet  \
# 33350  ma_train_01352  عندما كان المغربي يجاهد لتحرير ارضه في الصحراء...
# 35585  ma_train_03587  كلما في الامر هو ان بن كيران رجل صالح وادى الا...
# 34410  ma_train_02412  تحية احترام للسياسي و المناضل و من يقول الحق و...
# 33891  ma_train_01893  نحن لا نتكلم من منطق عنصري و لكن ضاق بنا الحال...
# 51883  yo_train_04308  #Yoruba Yoruba people please help me find this...
# ...               ...                                                ...
# 11044  ha_train_03410  @user @user 🤣🤣🤣🤣🤣🤣 Kai abun ya fara isarka ken...
# 14993  ha_train_07359                          @user Ya kai bayajiddah?🤔
# 7598   dz_train_01615                                        @user بزاف😍
# 22949  ig_train_01143  @user @user @user @user @user @user @user @use...
# 6363   dz_train_00380  @user @user @user @user 🤣🤣🤣🤣واقيل مزالك مريض ع...
#
#           label language  text_len_initial  \
# 33350  positive       ma               771
# 35585  positive       ma               510
# 34410  positive       ma               437
# 33891  negative       ma               441
# 51883   neutral       yo               274
# ...         ...      ...               ...
# 11044  negative       ha               111
# 14993   neutral       ha                25
# 7598   positive       dz                11
# 22949  negative       ig               143
# 6363   negative       dz                55
#
#                                                    words  num_words
# 33350  [عندما, كان, المغربي, يجاهد, لتحرير, ارضه, في,...         78
# 35585  [كلما, في, الامر, هو, ان, بن, كيران, رجل, صالح...         62
# 34410  [تحية, احترام, للسياسي, و, المناضل, و, من, يقو...         52
# 33891  [نحن, لا, نتكلم, من, منطق, عنصري, و, لكن, ضاق,...         51
# 51883  [#yoruba, yoruba, people, please, help, me, fi...         48
# ...                                                  ...        ...
# 11044  [@user, @user, 🤣🤣🤣🤣🤣🤣, kai, abun, ya, fara, is...          0
# 14993                     [@user, ya, kai, bayajiddah?🤔]          0
# 7598                                      [@user, بزاف😍]          0
# 22949  [@user, @user, @user, @user, @user, @user, @us...          0
# 6363   [@user, @user, @user, @user, 🤣🤣🤣🤣واقيل, مزالك,...          0
#
# [56098 rows x 7 columns]

# %%
df_filtered = df_raw_combined_new[df_raw_combined_new['text_len_initial'] > 280]
df_filtered
# Out:
#                    ID                                              tweet  \
# 7635   ha_train_00001  @user Da kudin da Arewa babu wani abin azo aga...
# 7640   ha_train_00006  @user To Ku nemawa talakkawa mafita mana, Maga...
# 7707   ha_train_00073  @user bandicts Jiya ma da daddare sunshiga gar...
# 7833   ha_train_00199  @user Inbanda rashin imani ma kai wanene da za...
# 7868   ha_train_00234  @user Durun uwar bomb din, kutumar ubanku daka...
# ...               ...                                                ...
# 55534  yo_train_07959  Akuu ayeye ayajo awon ewe . Aseyi samodun o. A...
# 55587  yo_train_08012  Yorùbá adage for the week: """"""""Ìrírí ayé ò...
# 55653  yo_train_08078  Ẹ KÁÁRỌ̀ Ẹ̀YIN ÈÈYÀN MI... 😍 AÀ JÍIRE BÍ O? 🤷‍...
# 55798  yo_train_08223  Ọwọ́ ọmọdé ò tó pẹpẹ; ti àgbàlagbà ò wọ akèrèg...
# 55976  yo_train_08401  Inú wa dùn láti kéde pé àwọn wọ̀nyí ni àkọ́yàn...
#
#           label language  text_len_initial  \
# 7635   negative       ha               283
# 7640   negative       ha               285
# 7707   negative       ha               288
# 7833   negative       ha               284
# 7868   negative       ha               281
# ...         ...      ...               ...
# 55534  positive       yo               285
# 55587  positive       yo               309
# 55653  positive       yo               287
# 55798  positive       yo               283
# 55976  positive       yo               286
#
#                                                    words  num_words
# 7635   [@user, da, kudin, da, arewa, babu, wani, abin...         23
# 7640   [@user, to, ku, nemawa, talakkawa, mafita, man...         23
# 7707   [@user, bandicts, jiya, ma, da, daddare, sunsh...         14
# 7833   [@user, inbanda, rashin, imani, ma, kai, wanen...         26
# 7868   [@user, durun, uwar, bomb, din,, kutumar, uban...         24
# ...                                                  ...        ...
# 55534  [akuu, ayeye, ayajo, awon, ewe, ., aseyi, samo...         28
# 55587  [yorùbá, adage, for, the, week:, """"""""ìrírí...         15
# 55653  [ẹ, káárọ̀, ẹ̀yin, èèyàn, mi..., 😍, aà, jíire,...         24
# 55798  [ọwọ́, ọmọdé, ò, tó, pẹpẹ;, ti, àgbàlagbà, ò, ...         28
# 55976  [inú, wa, dùn, láti, kéde, pé, àwọn, wọ̀nyí, n...         20
#
# [302 rows x 7 columns]

# %%
df_filtered2 = df_raw_combined_new[df_raw_combined_new['text_len_initial'] <= 280]
df_filtered2
# Out:
#                    ID                                              tweet  \
# 0      am_train_00001  Tesfaye ለካስ ጭብል ለብሰሽ የፕሮፌሰርን ፎቶ ለጥፈክ እልም ያልክ ባ...
# 1      am_train_00002  ይሄው ነው አይደል የእውቀትሽ ጥግ....በሰሚ ሰሚ ከምትናገሪ ለምን ታሪክ...
# 2      am_train_00003                ዘገበ ይባላል? ሌላ የሚባል ነገር ካለ አንተዉ ንገረን!
# 3      am_train_00004  ?? ድሮ በዘመነ ኮዳክ ፎቶ ቤት ፍላሹ ፏ ሲል አይናችን ተጨፍኖ እንዳይወ...
# 4      am_train_00005                                     ዠልጥ?? ???? ገገማ
# ...               ...                                                ...
# 56093  yo_train_08518  RT @user: Oju adan o'nribi, oju awodi o'nri or...
# 56094  yo_train_08519  a tú dúpẹ́ lọ́wọ́ àwọn alátakò wá náà, a ó gbọ...
# 56095  yo_train_08520  Ẹní tó làná, tó lòní, kò leè lọ̀la; Ọlọ́run nì...
# 56096  yo_train_08521  My God is """"""""onise iyanu"""""""" ( A Mira...
# 56097  yo_train_08522  RT @user: Ẹ wá ba mi re! #yorubafood #naijafoo...
#
#           label language  text_len_initial  \
# 0      negative       am                58
# 1      negative       am                70
# 2      negative       am                35
# 3      negative       am               113
# 4      negative       am                14
# ...         ...      ...               ...
# 56093  positive       yo               123
# 56094  positive       yo               202
# 56095  positive       yo               274
# 56096  positive       yo                65
# 56097  positive       yo                83
#
#                                                    words  num_words
# 0      [tesfaye, ለካስ, ጭብል, ለብሰሽ, የፕሮፌሰርን, ፎቶ, ለጥፈክ, እ...          7
# 1      [ይሄው, ነው, አይደል, የእውቀትሽ, ጥግ....በሰሚ, ሰሚ, ከምትናገሪ,...          3
# 2           [ዘገበ, ይባላል?, ሌላ, የሚባል, ነገር, ካለ, አንተዉ, ንገረን!]          6
# 3      [??, ድሮ, በዘመነ, ኮዳክ, ፎቶ, ቤት, ፍላሹ, ፏ, ሲል, አይናችን,...         12
# 4                                     [ዠልጥ??, ????, ገገማ]          2
# ...                                                  ...        ...
# 56093  [rt, @user:, oju, adan, o'nribi,, oju, awodi, ...         15
# 56094  [a, tú, dúpẹ́, lọ́wọ́, àwọn, alátakò, wá, náà,...         13
# 56095  [ẹní, tó, làná,, tó, lòní,, kò, leè, lọ̀la;, ọ...         29
# 56096  [my, god, is, """"""""onise, iyanu"""""""", (,...          4
# 56097  [rt, @user:, ẹ, wá, ba, mi, re!, #yorubafood, ...          6
#
# [55796 rows x 7 columns]

# %%
sns.boxplot(x="label", y="text_len_initial", data=df_filtered2, 
            palette=['#B81D13','#F7DB80','#008450'])


plt.title("Text Length across three labels")
plt.savefig("text_length_2.png")

# %% [markdown]
# ## Wordcloud

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
# %matplotlib inline
from wordcloud import (WordCloud, get_single_color_func)
from collections import Counter
import random

# %%
class SimpleGroupedColorFunc(object):
    """Create a color function object which assigns EXACT colors
       to certain words based on the color to words mapping
       Parameters
       ----------
       color_to_words : dict(str -> list(str))
         A dictionary that maps a color to the list of words.
       default_color : str
         Color that will be assigned to a word that's not a member
         of any value from color_to_words.
    """

    def __init__(self, color_to_words, default_color):
        self.word_to_color = {word: color
                              for (color, words) in color_to_words.items()
                              for word in words}

        self.default_color = default_color

    def __call__(self, word, **kwargs):
        return self.word_to_color.get(word, self.default_color)


def wordcloud_builder(df, df_name):
    
    
    # approach 1
    n = 20 #change this value to get top n elements by label
    df_wc = df.explode('words').groupby('label')['words'].value_counts().reset_index(name='count')
    df_wc = df_wc.groupby('label').head(n)   
    
    # approach 2
    #df_wc = df[['label', 'words']]
    #df_wc = df_wc.explode('words')
    
    # print(df_wc)

    labels_list = ['negative','neutral','positive']
    colors_list = ['red', 'yellow', 'green']
    colors_hex = ['#ed230a','#f8db30','#4c9a2b']

    label_conditions = [
        (df_wc['label'] == labels_list[0]),
        (df_wc['label'] == labels_list[1]), 
        (df_wc['label'] == labels_list[2])
    ]

    df_wc['color'] = np.select(label_conditions, colors_hex)
    
    #create a dict of colors and matching movies
    color_to_words = df_wc.groupby('color')['words'].agg(list).to_dict()
    #print(color_to_words)

    #Creating the text variable
    word_ls = df_wc.words
    #print(word_ls)

    #Creating a count (I want the words to be the same size) #### CAN BE CHANGED
    word_could_dict = Counter(word_ls)
    #print(word_could_dict)

    # Creating word_cloud with text as argument in .generate() method
    if df_name == 'df_am':
        wordcloud = WordCloud(font_path=r'fonts/jiretsl.ttf',min_font_size=18, max_font_size=72).generate_from_frequencies(word_could_dict)
    elif df_name == 'df_dz':
        wordcloud = WordCloud(font_path=r'fonts/ALGERIA_Bold/algerian_bold.ttf', min_font_size=24, max_font_size=72).generate_from_frequencies(word_could_dict)
    elif df_name == 'df_ma':
        wordcloud = WordCloud(font_path=r'fonts/MA_Arabic/UthmanTahaNaskhRegular.ttf', min_font_size=24, max_font_size=72).generate_from_frequencies(word_could_dict)
    else:
        wordcloud = WordCloud().generate_from_frequencies(word_could_dict)
    
    # Words that are not in any of the color_to_words values
    # will be colored with a grey single color function
    default_color = 'grey'

    # Create a color function with single tone
    grouped_color_func = SimpleGroupedColorFunc(color_to_words, default_color)

    # Apply our color function
    wordcloud.recolor(color_func=grouped_color_func)
    
    return wordcloud

# %%
# Sample wordcloud for combined datafile

# wordcloud = wordcloud_builder(df_translated_combined_new)

# # Display the generated Word Cloud
# plt.imshow(wordcloud, interpolation='bilinear')
# plt.axis("off")
# plt.show()

# %%
df_wcc = df_ha.explode('words')
df_wcc
# Out:
#                    ID                                              tweet  \
# 0      ha_train_00001  @user Da kudin da Arewa babu wani abin azo aga...
# 0      ha_train_00001  @user Da kudin da Arewa babu wani abin azo aga...
# 0      ha_train_00001  @user Da kudin da Arewa babu wani abin azo aga...
# 0      ha_train_00001  @user Da kudin da Arewa babu wani abin azo aga...
# 0      ha_train_00001  @user Da kudin da Arewa babu wani abin azo aga...
# ...               ...                                                ...
# 14171  ha_train_14172  @user @user Baka film din banza director Allah...
# 14171  ha_train_14172  @user @user Baka film din banza director Allah...
# 14171  ha_train_14172  @user @user Baka film din banza director Allah...
# 14171  ha_train_14172  @user @user Baka film din banza director Allah...
# 14171  ha_train_14172  @user @user Baka film din banza director Allah...
#
#           label   words
# 0      negative   kudin
# 0      negative   arewa
# 0      negative    babu
# 0      negative    wani
# 0      negative    abin
# ...         ...     ...
# 14171  positive     zai
# 14171  positive  daidai
# 14171  positive    abnd
# 14171  positive     ake
# 14171  positive  bukata
#
# [136169 rows x 4 columns]

# %%
# wordcloud for amharic datafile

wordcloud = wordcloud_builder(df_am,"df_am")

# Display the generated Word Cloud
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# font_path='jiretsl.ttf'

# %%
# wordcloud for algerian arabic datafile

wordcloud = wordcloud_builder(df_dz,"df_dz")

# Display the generated Word Cloud
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# font_path='jiretsl.ttf'

# %%
# wordcloud for algerian arabic datafile

wordcloud = wordcloud_builder(df_ma,"df_ma")

# Display the generated Word Cloud
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# font_path='jiretsl.ttf'
# Out:
#           label    words  count
# 0      negative      على    209
# 1      negative     الله    204
# 2      negative      هذا     80
# 3      negative      chi     72
# 4      negative      ana     68
# 5      negative      ولا     67
# 6      negative     ghir     62
# 7      negative      rah     61
# 8      negative    الشعب     61
# 9      negative  بنكيران     60
# 11413   neutral      على    244
# 11414   neutral      ana    202
# 11415   neutral     ghir    132
# 11416   neutral     ديال    131
# 11417   neutral      rah    129
# 11418   neutral      chi    124
# 11419   neutral     اللي    118
# 11420   neutral   المغرب     83
# 11421   neutral  الحكومة     70
# 11422   neutral      وها     64
# 23971  positive     الله    290
# 23972  positive      على    140
# 23973  positive      ana     98
# 23974  positive  بنكيران     89
# 23975  positive      lik     79
# 23976  positive   المغرب     68
# 23977  positive      شاء     53
# 23978  positive  العدالة     45
# 23979  positive      hna     42
# 23980  positive     ihab     41

# %%
import time;
ts = time.time()
print(ts)
# Out:
# 1669858805.694423

# %%
# African Language Wordclouds

plt.subplots(figsize=(16,8))

for i, (df_name, df) in enumerate(raw_dfs_dict.items()):
    #print("\n",df_name,"\n")
    df = preprocessing(df)
    df_name_new = df_name.split("_")[1]
    #print(df_name_new)
    wordcloud = wordcloud_builder(df, df_name)
    plt.subplot(3, 3, i+1)
    plt.imshow(wordcloud, interpolation="bilinear")
    plt.axis("off")
    plt.title(df_name_new.upper())

# Legend
red_patch = mpatches.Patch(color='#ed230a', label='Negative')
yellow_patch = mpatches.Patch(color='#f8db30', label='Neutral')
green_patch = mpatches.Patch(color='#4c9a2b', label='Positive')
handles=[red_patch,yellow_patch,green_patch]
labels = ['Negative','Neutral','Positive']
plt.figlegend(handles, labels, loc = 'upper right', ncol=5, labelspacing=0.)

# Add overall title
plt.suptitle("African Language WordClouds", fontsize=20)

# Combine all the plots, save image and display
ts = time.time()
ts = str(ts)
ts = ts.split(".")[1]
image_name = "wordclouds_" + ts + ".png"
# print(image_name)
plt.savefig(image_name)
plt.show()

# %%
# English Translated Wordclouds
import matplotlib.pyplot as plt

plt.subplots(figsize=(16,8))

for i, (df_name, df) in enumerate(translated_dfs_dict.items()):
    df = preprocessing(df)
    df_name_new = df_name.split("_")[1]
    #print(df_name_new)
    wordcloud = wordcloud_builder(df,df_name)
    plt.subplot(3, 3, i+1)
    plt.imshow(wordcloud, interpolation="bilinear")
    plt.axis("off")
    plt.title(df_name_new.upper() + " Language")

# Legend
red_patch = mpatches.Patch(color='#ed230a', label='Negative')
yellow_patch = mpatches.Patch(color='#f8db30', label='Neutral')
green_patch = mpatches.Patch(color='#4c9a2b', label='Positive')
handles=[red_patch,yellow_patch,green_patch]
labels = ['Negative','Neutral','Positive']
plt.figlegend(handles, labels, loc = 'upper right', ncol=5, labelspacing=0.)

# Add overall title
plt.suptitle("English Translated WordClouds", fontsize=20)

# Combine all the plots, save image and display
plt.savefig("wordclouds_english.png")
plt.show()
